# %%
import pandas as pd
import numpy as np
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': 'The validate_docstrings.py validator was returning errors for methods with no comments. I only worked on the methods that already had comments in this PR.\r\n\r\n- works on #24070\r\n\r\n',
#   'closed_at': None,
#   'comments': 1,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/24243/comments',
#   'created_at': '2018-12-11T21:58:37Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/24243/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/24243',
#   'id': 389971600,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/24243/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MjM3ODQxMzU4',
#   'number': 24243,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/24243.diff',
# ...

# %%
data[0]['title']
# Out:
# 'DOC: Fix quotes position in Timestamp and Timedelta'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'laels', 'state'])
issues
# Out:
#     number                                              title  laels state
# 0    24243  DOC: Fix quotes position in Timestamp and Time...    NaN  open
# 1    24242  TST: Hypothesis may draw a date outside of dat...    NaN  open
# 2    24241  Series.apply on categorical with NaN has wrong...    NaN  open
# 3    24240  DOC: Fix flake8 issues in doc/source/whatsnew/...    NaN  open
# 4    24239   DOC: Fix flake8 issues in doc/source/whatsnew...    NaN  open
# 5    24238  DOC: avoid warnings ipython 'Code input with n...    NaN  open
# 6    24237  DOC: Fix flake8 issues in doc/source/whatsnew/...    NaN  open
# 7    24236        Fix flake8 issues on v19, v20 and v21.0.rst    NaN  open
# 8    24235  DOC: Fix flake8 issues in doc/source/whatsnew/...    NaN  open
# 9    24233  DOC: Fix flake8 issues in doc/source/whatsnew/...    NaN  open
# 10   24231    Rename DatetimeArrayMixin / TimedeltaArrayMixin    NaN  open
# ...
